# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style = 'darkgrid')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

# %%
rng = np.random.RandomState(1)
X = 10 * rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)
X_new = np.linspace(0, 10, 1000)

# %%
#creating a pipeline to fit a polynomial to the linear model
poly_model = make_pipeline(PolynomialFeatures(8),LinearRegression())

# %%
poly_model.fit(X[:, np.newaxis], y)
y_pred = poly_model.predict(X_new[:, np.newaxis])
plt.scatter(X, y)
plt.plot(X_new, y_pred);

# %% [markdown]
# ## fitting a linear regression line

# %%
rng = np.random.RandomState(1)
X1 = 10 * rng.rand(50)
y1 = 2 * x - 5 + rng.randn(50)

# %%
#instantiating the model, fitting the model to the data points and predicting 
model = LinearRegression(fit_intercept=True)
model.fit(X1[:, np.newaxis], y1)
y_pred1 = model.predict(X_new[:, np.newaxis])

# %%
#plotting the graph
fig,ax = plt.subplots(1,2, figsize= [15,5])
ax[0].scatter(X1, y1,)
ax[1].scatter(X1, y1)
ax[1].plot(X_new, y_pred1)
ax[0].set(xlabel='x1', ylabel='y1', ylim=(y1.min() -2, y1.max() + 2))
ax[1].set(xlabel='x', ylabel='y', ylim=(y1.min() -2, y1.max() + 2))
ax[1].annotate('pred_y',(6.7,8.4),(7,1), arrowprops = dict(arrowstyle ='->',color='k'),fontsize = 15)
plt.suptitle('Scatter graph showing the unpredicted (left) and predicted y (right)');
plt.annotate
# Out:
# <function matplotlib.pyplot.annotate(s, xy, *args, **kwargs)>

# %%
print(f'Model intercept: {model.intercept_}\nModel coef: {model.coef_[0]}')
# Out:
# Model intercept: -4.998577085553198
# Model coef: 2.027208810360694
